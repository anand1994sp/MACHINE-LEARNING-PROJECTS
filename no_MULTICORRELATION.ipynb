# %% [markdown]
# <a href="https://colab.research.google.com/github/anand1994sp/MACHINE-LEARNING-PROJECTS/blob/main/no_MULTICORRELATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=load_boston()
df=pd.DataFrame(d.data,columns=d.feature_names)
df["MEDV"]=d.target
df.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
d.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
x=df.drop("MEDV",axis=1)
y=df["MEDV"]

# %%
x.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT
# 0     15.3  396.9   4.98
# 1     17.8  396.9   9.14

# %%
y.head(2)
# Out:
# 0    24.0
# 1    21.6
# Name: MEDV, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
xtrain.shape,xtest.shape
# Out:
# ((354, 13), (152, 13))

# %%
corr=xtrain.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.179080  0.360532 -0.038810  0.388155 -0.168756  0.322089
# ZN      -0.179080  1.000000 -0.510222 -0.046753 -0.494011  0.249429 -0.550763
# INDUS    0.360532 -0.510222  1.000000  0.074988  0.752948 -0.341933  0.642210
# CHAS    -0.038810 -0.046753  0.074988  1.000000  0.072067  0.096385  0.092397
# NOX      0.388155 -0.494011  0.752948  0.072067  1.000000 -0.264582  0.717135
# RM      -0.168756  0.249429 -0.341933  0.096385 -0.264582  1.000000 -0.215241
# AGE      0.322089 -0.550763  0.642210  0.092397  0.717135 -0.215241  1.000000
# DIS     -0.339979  0.653696 -0.697592 -0.108532 -0.753636  0.154725 -0.733256
# RAD      0.577388 -0.288705  0.563103  0.004684  0.588333 -0.169489  0.438396
# TAX      0.533345 -0.296310  0.696777 -0.024793  0.655317 -0.246368  0.495789
# PTRATIO  0.256815 -0.370663  0.344170 -0.085811  0.143318 -0.300178  0.235441
# ...

# %%
from seaborn.widgets import color_palette
import seaborn as sns
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cmap="cividis")

# %%
def corr_extract(data,threshold):
  corrr=set()
  corr=data.corr()
  for i in range(len(corr.columns)):
    for j in range(i):
      if abs(corr.iloc[i,j])>threshold:
        colname=corr.columns[i]
        corrr.add(colname)
  return corr

# %%
corr_features=corr_extract(xtrain,0.7)
corr_features
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.179080  0.360532 -0.038810  0.388155 -0.168756  0.322089
# ZN      -0.179080  1.000000 -0.510222 -0.046753 -0.494011  0.249429 -0.550763
# INDUS    0.360532 -0.510222  1.000000  0.074988  0.752948 -0.341933  0.642210
# CHAS    -0.038810 -0.046753  0.074988  1.000000  0.072067  0.096385  0.092397
# NOX      0.388155 -0.494011  0.752948  0.072067  1.000000 -0.264582  0.717135
# RM      -0.168756  0.249429 -0.341933  0.096385 -0.264582  1.000000 -0.215241
# AGE      0.322089 -0.550763  0.642210  0.092397  0.717135 -0.215241  1.000000
# DIS     -0.339979  0.653696 -0.697592 -0.108532 -0.753636  0.154725 -0.733256
# RAD      0.577388 -0.288705  0.563103  0.004684  0.588333 -0.169489  0.438396
# TAX      0.533345 -0.296310  0.696777 -0.024793  0.655317 -0.246368  0.495789
# PTRATIO  0.256815 -0.370663  0.344170 -0.085811  0.143318 -0.300178  0.235441
# ...

# %%
len(corr_features)
# Out:
# 13

# %%
xtrain.drop(corr_features,axis=1)
xtest.drop(corr_features,axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [463, 152, 291, 183, 384, 141, 240, 349, 410, 150, 175, 289, 67, 310, 376, 1, 221, 439, 415, 447, 334, 103, 264, 461, 420, 18, 161, 198, 55, 332, 422, 335, 193, 65, 403, 146, 382, 357, 176, 77, 301, 20, 89, 386, 480, 393, 192, 442, 259, 412, 178, 266, 398, 281, 407, 28, 337, 499, 24, 212, 297, 355, 317, 307, 279, 100, 203, 222, 389, 285, 32, 387, 502, 469, 236, 504, 171, 230, 66, 84, 40, 109, 464, 41, 226, 258, 479, 173, 300, 465, 69, 14, 381, 256, 268, 425, 228, 200, 12, 129, ...]
#
# [152 rows x 0 columns]

# %%
xtest.shape
# Out:
# (152, 13)
